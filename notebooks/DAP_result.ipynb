# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
tracin_config = pd.read_feather("/Users/hb70ur/Downloads/Moons_tracin_config.ft")

# %%
tracin_config
# Out:
#                        index                       hidden_channels      lr  \
# 0      Moons_0-kiddy_model_0                      [30, 100, 50, 1]  0.0001
# 1      Moons_0-kiddy_model_1                      [30, 100, 50, 1]  0.0001
# 2      Moons_0-kiddy_model_2                      [30, 100, 50, 1]  0.0001
# 3      Moons_0-kiddy_model_3                      [30, 100, 50, 1]  0.0010
# 4      Moons_0-kiddy_model_4                      [30, 100, 50, 1]  0.0010
# ...                      ...                                   ...     ...
# 1075   Moons_44-deep_model_7  [60, 200, 400, 400, 200, 100, 50, 1]  0.0100
# 1076   Moons_44-deep_model_8  [60, 200, 400, 400, 200, 100, 50, 1]  0.0100
# 1077   Moons_44-deep_model_9  [60, 200, 400, 400, 200, 100, 50, 1]  0.0300
# 1078  Moons_44-deep_model_10  [60, 200, 400, 400, 200, 100, 50, 1]  0.0300
# 1079  Moons_44-deep_model_11  [60, 200, 400, 400, 200, 100, 50, 1]  0.0300
#
#       patience  frequency
# 0            3          3
# ...

# %%
tracin_config[tracin_config['index'] == "Moons_18-deep_model_11"]
# Out:
#                       index                       hidden_channels    lr  \
# 455  Moons_18-deep_model_11  [60, 200, 400, 400, 200, 100, 50, 1]  0.03
#
#      patience  frequency
# 455        15         10

# %%
arr0 = np.load("/Users/hb70ur/Downloads/results_40/Moons_18-deep_model_8-tracin_2.npy")

# %%
sns.heatmap(arr0.T[iter][:1600].reshape(40,40))
# Out:
# <Axes: >

# %%
arr1 = np.load("/Users/hb70ur/Downloads/results_40/Moons_18-deep_model_8-tracin_6.npy")

# %%
sns.heatmap(arr1.T[iter][:1600].reshape(40,40))
# Out:
# <Axes: >

# %%
iter = 7

# %%
sns.heatmap(arr0.T[iter][:1600].reshape(40,40) + arr1.T[iter][:1600].reshape(40,40))
# Out:
# <Axes: >
